# %% [markdown]
# ##### БМД, БС-83,Гулякевич

# %%
import pandas as pd

# %%
import pandas as pd
new_df = pd.DataFrame(
{"Names of students":["Eva","Oleg","Pasha","Anna","Vlad"],
 "Students, who have good marks":["True","False","True","True","False"],
 "Students , who work": ["works","unemployed","works","unemployed","unemployed"],
 "Headman and his assistant": ["usual student","usual student","headman","assistant","usual student"],
 "Students who always pass exam from the first time":["True","False","True","True","True"],
 "Students avarage marks":[95,60,95,86,74]
})
new_df
# Out:
#   Names of students Students, who have good marks Students , who work  \
# 0               Eva                          True               works
# 1              Oleg                         False          unemployed
# 2             Pasha                          True               works
# 3              Anna                          True          unemployed
# 4              Vlad                         False          unemployed
#
#   Headman and his assistant Students who always pass exam from the first time  \
# 0             usual student                                              True
# 1             usual student                                             False
# 2                   headman                                              True
# 3                 assistant                                              True
# 4             usual student                                              True
#
#    Students avarage marks
# 0                      95
# ...

# %%
path = "D:\бмд\кп1\coronavirusdataset\PatientInfo.csv"
data = pd.read_csv(path, encoding = 'utf-8')
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
import os
print ("The directory we are working in is: {}".format(os.getcwd()))
# Out:
# The directory we are working in is: C:\Users\lanag

# %%
data=pd.read_csv("D:\бмд\кп1\coronavirusdataset\PatientInfo.csv")
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data
# Out:
#       patient_id  global_num     sex  birth_year  age        country province  \
# 0     1000000001         2.0    male      1964.0  50s          Korea    Seoul
# 1     1000000002         5.0    male      1987.0  30s          Korea    Seoul
# 2     1000000003         6.0    male      1964.0  50s          Korea    Seoul
# 3     1000000004         7.0    male      1991.0  20s          Korea    Seoul
# 4     1000000005         9.0  female      1992.0  20s          Korea    Seoul
# ...          ...         ...     ...         ...  ...            ...      ...
# 2766  7000000005      9120.0  female         NaN  20s          Korea  Jeju-do
# 2767  7000000006      9087.0    male         NaN  30s  United States  Jeju-do
# 2768  7000000007         NaN  female      1996.0  20s          Korea  Jeju-do
# 2769  7000000008         NaN  female         NaN  10s          Korea  Jeju-do
# 2770  7000000009         NaN  female         NaN  20s          Korea  Jeju-do
#
# ...

# %%
data.shape
# Out:
# (2771, 18)

# %%
data.head()
# Out:
#    patient_id  global_num     sex  birth_year  age country province  \
# 0  1000000001         2.0    male      1964.0  50s   Korea    Seoul
# 1  1000000002         5.0    male      1987.0  30s   Korea    Seoul
# 2  1000000003         6.0    male      1964.0  50s   Korea    Seoul
# 3  1000000004         7.0    male      1991.0  20s   Korea    Seoul
# 4  1000000005         9.0  female      1992.0  20s   Korea    Seoul
#
#           city disease        infection_case  infection_order   infected_by  \
# 0   Gangseo-gu     NaN       overseas inflow              1.0           NaN
# 1  Jungnang-gu     NaN       overseas inflow              1.0           NaN
# 2    Jongno-gu     NaN  contact with patient              2.0  2.002000e+09
# 3      Mapo-gu     NaN       overseas inflow              1.0           NaN
# 4  Seongbuk-gu     NaN  contact with patient              2.0  1.000000e+09
#
#    contact_number symptom_onset_date confirmed_date released_date  \
# ...

# %%
data.tail()
# Out:
#       patient_id  global_num     sex  birth_year  age        country province  \
# 2766  7000000005      9120.0  female         NaN  20s          Korea  Jeju-do
# 2767  7000000006      9087.0    male         NaN  30s  United States  Jeju-do
# 2768  7000000007         NaN  female      1996.0  20s          Korea  Jeju-do
# 2769  7000000008         NaN  female         NaN  10s          Korea  Jeju-do
# 2770  7000000009         NaN  female         NaN  20s          Korea  Jeju-do
#
#          city disease   infection_case  infection_order  infected_by  \
# 2766  Jeju-do     NaN  overseas inflow              NaN          NaN
# 2767  Jeju-do     NaN  overseas inflow              NaN          NaN
# 2768  Jeju-do     NaN  overseas inflow              NaN          NaN
# 2769  Jeju-do     NaN  overseas inflow              NaN          NaN
# 2770  Jeju-do     NaN  overseas inflow              NaN          NaN
#
#       contact_number symptom_onset_date confirmed_date released_date  \
# ...

# %%
data.dtypes
# Out:
# patient_id              int64
# global_num            float64
# sex                    object
# birth_year            float64
# age                    object
# country                object
# province               object
# city                   object
# disease                object
# infection_case         object
# infection_order       float64
# infected_by           float64
# contact_number        float64
# symptom_onset_date     object
# confirmed_date         object
# released_date          object
# deceased_date          object
# state                  object
# dtype: object

# %%
data.describe()
# Out:
#          patient_id   global_num   birth_year  infection_order   infected_by  \
# count  2.771000e+03  1664.000000  2414.000000        31.000000  6.500000e+02
# mean   3.748468e+09  5558.304087  1974.374896         2.387097  2.647075e+09
# std    2.209410e+09  3142.434246    20.284689         1.453213  1.687647e+09
# min    1.000000e+09     1.000000  1916.000000         1.000000  1.000000e+09
# 25%    1.400000e+09  2693.500000  1960.000000         1.000000  1.200000e+09
# 50%    4.100000e+09  6344.500000  1974.000000         2.000000  2.000000e+09
# 75%    6.001001e+09  8268.250000  1993.000000         3.000000  4.100000e+09
# max    7.000000e+09  9652.000000  2020.000000         6.000000  6.100000e+09
#
#        contact_number
# count      517.000000
# mean        20.849130
# std         81.595859
# min          0.000000
# 25%          2.000000
# 50%          5.000000
# 75%         15.000000
# max       1160.000000

# %%
data['infected_by'].describe()
# Out:
# count    6.500000e+02
# mean     2.647075e+09
# std      1.687647e+09
# min      1.000000e+09
# 25%      1.200000e+09
# 50%      2.000000e+09
# 75%      4.100000e+09
# max      6.100000e+09
# Name: infected_by, dtype: float64

# %%
cut_data=data.iloc[0:10,:]
cut_data
# Out:
#    patient_id  global_num     sex  birth_year  age country province  \
# 0  1000000001         2.0    male      1964.0  50s   Korea    Seoul
# 1  1000000002         5.0    male      1987.0  30s   Korea    Seoul
# 2  1000000003         6.0    male      1964.0  50s   Korea    Seoul
# 3  1000000004         7.0    male      1991.0  20s   Korea    Seoul
# 4  1000000005         9.0  female      1992.0  20s   Korea    Seoul
# 5  1000000006        10.0  female      1966.0  50s   Korea    Seoul
# 6  1000000007        11.0    male      1995.0  20s   Korea    Seoul
# 7  1000000008        13.0    male      1992.0  20s   Korea    Seoul
# 8  1000000009        19.0    male      1983.0  30s   Korea    Seoul
# 9  1000000010        21.0  female      1960.0  60s   Korea    Seoul
#
#           city disease        infection_case  infection_order   infected_by  \
# 0   Gangseo-gu     NaN       overseas inflow              1.0           NaN
# ...

# %%
new_data=["gr1","gr1","gr1","gr1","gr1","gr2","gr2","gr2","gr2","gr2"]
cut_data.insert(1,"Group", new_data)
cut_data
# Out:
#    patient_id Group  global_num     sex  birth_year  age country province  \
# 0  1000000001   gr1         2.0    male      1964.0  50s   Korea    Seoul
# 1  1000000002   gr1         5.0    male      1987.0  30s   Korea    Seoul
# 2  1000000003   gr1         6.0    male      1964.0  50s   Korea    Seoul
# 3  1000000004   gr1         7.0    male      1991.0  20s   Korea    Seoul
# 4  1000000005   gr1         9.0  female      1992.0  20s   Korea    Seoul
# 5  1000000006   gr2        10.0  female      1966.0  50s   Korea    Seoul
# 6  1000000007   gr2        11.0    male      1995.0  20s   Korea    Seoul
# 7  1000000008   gr2        13.0    male      1992.0  20s   Korea    Seoul
# 8  1000000009   gr2        19.0    male      1983.0  30s   Korea    Seoul
# 9  1000000010   gr2        21.0  female      1960.0  60s   Korea    Seoul
#
#           city disease        infection_case  infection_order   infected_by  \
# 0   Gangseo-gu     NaN       overseas inflow              1.0           NaN
# ...

# %%
cut_data.groupby('Group').describe()
# Out:
#       patient_id                                                      \
#            count          mean       std           min           25%
# Group
# gr1          5.0  1.000000e+09  1.581139  1.000000e+09  1.000000e+09
# gr2          5.0  1.000000e+09  1.581139  1.000000e+09  1.000000e+09
#
#                                                 global_num        ...  \
#                 50%           75%           max      count  mean  ...
# Group                                                             ...
# gr1    1.000000e+09  1.000000e+09  1.000000e+09        5.0   5.8  ...
# gr2    1.000000e+09  1.000000e+09  1.000000e+09        5.0  14.8  ...
#
#         infected_by               contact_number                             \
#                 75%           max          count  mean        std  min  25%
# Group
# gr1    1.751500e+09  2.002000e+09            5.0  26.8  29.020682  2.0  9.0
# gr2    1.000000e+09  1.000000e+09            5.0  23.4  30.705048  0.0  0.0
#
#
# ...

# %%
cut_data.to_csv("output.csv", encoding='utf8')

# %%
data.to_csv("input.csv", encoding='utf8')
